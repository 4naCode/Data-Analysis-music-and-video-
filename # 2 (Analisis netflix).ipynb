# %% [markdown]
# # NEFLIX ANALIS

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('netflix.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.size
# Out:
# 105684

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# task 1. is there duplicate record in this dataset ? it yes. then remove the duplicate record

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
#remove
#df.drop_duplicated(inplase = True)
#df[df.duplicated()]
#df.shape

# %% [markdown]
# task 2 is there any null value present in any column ? show with heat-map

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#seborn library (heatmap)
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# Q1 For "Zombieland", what is the show id and who is the director of this show?

# %%
df[df['title'].isin(['Zombieland'])]
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
#
#             date_added  release_year rating duration                listed_in  \
# 8804  November 1, 2019          2009      R   88 min  Comedies, Horror Movies
#
#                                             description
# 8804  Looking to survive in a world taken over by zo...

# %%
df[df['title'].str.contains('Zombieland')]
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
#
#             date_added  release_year rating duration                listed_in  \
# 8804  November 1, 2019          2009      R   88 min  Comedies, Horror Movies
#
#                                             description
# 8804  Looking to survive in a world taken over by zo...

# %% [markdown]
# Q2 in which year highest number of the TV Show and Movie were released ? show with bar graph

# %%
#dtyipes
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date_added'])

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#dt.year.value_counts()
df['date'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: date, dtype: int64

# %%
#bar graps
df['date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Q3 how many movies and tv shows are in the dataset ? show with bargraph

# %%
#Goupby
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description       date
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
df['type'].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
df.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(df['type'])
# Out:
# C:\Users\agian\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: xlabel='type', ylabel='count'>

# %% [markdown]
# Q4 show all the movie that were realesed in year 2000

# %%
#create  neww colums
df['year'] = df['date'].dt.year

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description       date    year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
df['year'].value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: year, dtype: int64

# %%
df['country'].unique()
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
#filterring
df[(df['type'] == 'Movie') & (df['year'] == 2010)]
# Out:
#      show_id   type                        title    director  \
# 7370   s7371  Movie  Mad Ron's Prevues from Hell  Jim Monaco
#
#                                                    cast        country  \
# 7370  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
#
#             date_added  release_year rating duration  \
# 7370  November 1, 2010          1987     NR   84 min
#
#                        listed_in  \
# 7370  Cult Movies, Horror Movies
#
#                                             description       date    year
# 7370  This collection cherry-picks trailers, forgott... 2010-11-01  2010.0

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description       date    year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %% [markdown]
# Q5 show only the titles of tv shows that were realesed in india only.

# %%
#mencari all
df[(df['type'] == 'TV Show') & (df['country'] == 'South Africa')]
# Out:
#      show_id     type                  title director  \
# 1         s2  TV Show          Blood & Water      NaN
# 1514   s1515  TV Show           Diamond City      NaN
# 1535   s1536  TV Show  How To Ruin Christmas      NaN
# 1593   s1594  TV Show       Kings of Jo'Burg      NaN
# 2611   s2612  TV Show               Tjovitjo      NaN
# 2870   s2871  TV Show             Queen Sono      NaN
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1514  Noxee Maqashalala, Angela Sithole, Nambitha Be...  South Africa
# 1535                                                NaN  South Africa
# 1593  Shona Ferguson, Zolisa Xaluva, Tsholofelo Mats...  South Africa
# 2611  Warren Masemola, Nobulali Dangazele, Rapulana ...  South Africa
# 2870  Pearl Thusi, Vuyo Dabula, Loyiso Madinga, Kate...  South Africa
#
#               date_added  release_year rating   duration  \
# ...

# %%
#mencari berdasarkan title
df[(df['type'] == 'TV Show') & (df['country'] == 'South Africa')] ['title']
# Out:
# 1               Blood & Water
# 1514             Diamond City
# 1535    How To Ruin Christmas
# 1593         Kings of Jo'Burg
# 2611                 Tjovitjo
# 2870               Queen Sono
# Name: title, dtype: object

# %% [markdown]
# Q6 show top 10 director, who gave the hoghest number of TV show & movies to neflix?

# %%
df['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description       date    year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %% [markdown]
# Q7 show all the record, where "category is movie and type is comedles" or "county is united kingdom".

# %%
#hanya mencari dengan 2 premis
#df[(df['type'] == 'Movie') & (df['listed_in'] == 'Comedies')]
#menggunakan 3 premis
df[(df['type'] == 'Movie') & (df['listed_in'] == 'Comedies') | (df['country'] == 'United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %% [markdown]
# Q8 in how many Movies/show, Adam Sandler wwas cast ?

# %%
#filtering
df[df['cast'] == "Adam Sandler"]
# Out:
#      show_id   type                    title     director          cast  \
# 4482   s4483  Movie  ADAM SANDLER 100% FRESH  Steve Brill  Adam Sandler
#
#             country        date_added  release_year rating duration  \
# 4482  United States  October 23, 2018          2018  TV-MA   74 min
#
#             listed_in                                        description  \
# 4482  Stand-Up Comedy  From "Heroes" to "Ice Cream Ladies" – Adam San...
#
#            date    year
# 4482 2018-10-23  2018.0

# %%
df[df['cast'].str.contains('Adam Sandler')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26192/142399085.py in <module>
# ----> 1 df[df['cast'].str.contains('Adam Sandler')]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
# -> 3448         if com.is_bool_indexer(key):
#    3449             return self._getitem_bool_array(key)
#    3450
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %% [markdown]
# create data new free data nan

# %%
#menghapus data yg mengandunga nilai nan
dfNew = df.dropna()

# %%
dfNew.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
dfNew[dfNew['cast'].str.contains('Adam Sandler')]
# Out:
#      show_id   type                                      title  \
# 27       s28  Movie                                  Grown Ups
# 1879   s1880  Movie                            Hubie Halloween
# 2471   s2472  Movie                                 Uncut Gems
# 3753   s3754  Movie                             Murder Mystery
# 4482   s4483  Movie                    ADAM SANDLER 100% FRESH
# 4912   s4913  Movie                                The Week Of
# 5227   s5228  Movie  The Meyerowitz Stories (New and Selected)
# 5533   s5534  Movie                               Sandy Wexler
# 5846   s5847  Movie                                The Do-Over
# 5879   s5880  Movie                           The Ridiculous 6
# 6018   s6019  Movie                             50 First Dates
# 6164   s6165  Movie                           Anger Management
# 6271   s6272  Movie                            Bedtime Stories
# 6303   s6304  Movie                                  Big Daddy
# ...

# %% [markdown]
# Q9 what are the different ratings defined by neflix ?

# %%
df['rating'].nunique()
# Out:
# 17

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Q9.1 how many movies got the "TV-14" rating. in canada?

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description       date    year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
#df[(df['type'] == 'Movie') & (df['rating'] == 'TV-14')]
#df[(df['type'] == 'Movie') & (df['rating'] == 'TV-14')].shape
df[(df['type'] == 'Movie') & (df['rating'] == 'TV-14') & (df['country'] == 'Canada')].shape
# Out:
# (13, 14)

# %% [markdown]
# Q9.2 How many Tv Show got the 'R' rating, after year 2018 ?

# %%
df[(df['type'] == 'TV Show') & (df['rating'] == 'R') & (df['year'] > 2018)]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#           date_added  release_year rating  duration listed_in  \
# 3893  April 25, 2019          2015      R  1 Season  TV Shows
#
#                                             description       date    year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# Q10 What is the maximum duration of a movie / show on neflix ?

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description       date    year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
df['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df.duration.dtypes
# Out:
# dtype('O')

# %%
#str split
#creat colom baru
df[['Minutes', 'Unit']] = df['duration'].str.split(' ', expand = True)

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description       date    year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes     Unit
# ...

# %%
df[df['Minutes'].isna()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description  \
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...
#
#            date    year Minutes Unit
# 5541 2017-04-04  2017.0     NaN  NaN
# ...

# %%
#df['Minutes'].fillna(df['Minutes'].mean())
df["Minutes"]=df["Minutes"].fillna(df["Minutes"].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26192/2826611857.py in <module>
#       1 #df['Minutes'].fillna(df['Minutes'].mean())
# ----> 2 df["Minutes"]=df["Minutes"].fillna(df["Minutes"].mean())
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10367
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10369         return self._stat_function(
# ...

# %%
df['Minutes'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26192/2861061308.py in <module>
# ----> 1 df['Minutes'].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10367
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10369         return self._stat_function(
#   10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
# ...

# %%
df[df['Minutes'].isna()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description  \
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...
#
#            date    year Minutes Unit
# 5541 2017-04-04  2017.0     NaN  NaN
# ...

# %%
df[(df['director'] == 'Louis C.K.') & (df['country'] == 'United States')]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description  \
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...
#
#            date    year Minutes Unit
# 5541 2017-04-04  2017.0     NaN  NaN
# ...

# %%
df['Minutes'].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26192/1217551178.py in <module>
# ----> 1 df['Minutes'].max()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   10817         )
#   10818         def max(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10819             return NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#   10820
#   10821         setattr(cls, "max", max)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   10362
#   10363     def max(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10364         return self._stat_function(
#   10365             "max", nanops.nanmax, axis, skipna, level, numeric_only, **kwargs
# ...

# %% [markdown]
# Q 11 which individual county has the highest no. of Tv Shows ?

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description       date    year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes     Unit
# ...

# %%
df_tvshow = df[df['type'] == "TV Show"]
df_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description       date    year  \
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
# 2  To protect his family from a powerful drug lor... 2021-09-24  2021.0
#
#   Minutes     Unit
# 1       2  Seasons
# ...

# %%
df_tvshow.country.value_counts().head(10)
# Out:
# United States     760
# United Kingdom    213
# Japan             169
# South Korea       158
# India              79
# Taiwan             68
# Canada             59
# France             49
# Australia          48
# Spain              48
# Name: country, dtype: int64

# %% [markdown]
# Q 12 How can we sort the dataset by year ?

# %%
df.sort_values(by = "year").head(3)
# Out:
#      show_id     type                    title              director  \
# 5957   s5958    Movie     To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show          Dinner for Five                   NaN
# 5956   s5957    Movie  Just Another Love Story          Ole Bornedal
#
#                                                    cast        country  \
# 5957  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 6611                                                NaN  United States
# 5956  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
#
#             date_added  release_year rating  duration  \
# 5957   January 1, 2008          2006  TV-MA    81 min
# 6611  February 4, 2008          2007  TV-MA  1 Season
# 5956       May 5, 2009          2007  TV-MA   104 min
#
#                                   listed_in  \
# 5957  Dramas, Independent Movies, Thrillers
# 6611           Stand-Up Comedy & Talk Shows
# ...

# %%
df.sort_values(by = "year", ascending = False).head(3)
# Out:
#      show_id   type                               title         director  \
# 0         s1  Movie                Dick Johnson Is Dead  Kirsten Johnson
# 996     s997  Movie                          HOMUNCULUS  Takashi Shimizu
# 1005   s1006  Movie  Keymon and Nani in Space Adventure              NaN
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 996   Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...          Japan
# 1005                                                NaN            NaN
#
#               date_added  release_year rating duration  \
# 0     September 25, 2021          2020  PG-13   90 min
# 996       April 22, 2021          2021  TV-MA  116 min
# 1005      April 20, 2021          2013   TV-Y   76 min
#
#                                            listed_in  \
# 0                                      Documentaries
# ...

# %% [markdown]
# Q 13 find all the instamces where :
# - type is "movie" and listed_in "dramas"
# or
# - type is "TV show" and listed_in is "Kids TV"

# %%
df[(df['type'] == 'Movie') & (df['listed_in'] == 'Dramas')].head(2)
# Out:
#     show_id   type               title         director  \
# 112    s113  Movie               Worth   Sara Colangelo
# 129    s130  Movie  An Unfinished Life  Lasse Hallström
#
#                                                   cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
#
#                     country         date_added  release_year rating duration  \
# 112                     NaN  September 3, 2021          2021  PG-13  119 min
# 129  Germany, United States  September 1, 2021          2005  PG-13  108 min
#
#     listed_in                                        description       date  \
# 112    Dramas  In the wake of the Sept. 11 attacks, a lawyer ... 2021-09-03
# 129    Dramas  A grieving widow and her daughter move in with... 2021-09-01
#
#        year Minutes Unit
# 112  2021.0     119  min
# 129  2021.0     108  min

# %%
df[(df['type'] == 'TV Show') & (df['listed_in'] == "Kids' TV")].head(2)
# Out:
#    show_id     type                    title director  \
# 34     s35  TV Show  Tayo and Little Wizards      NaN
# 39     s40  TV Show             Chhota Bheem      NaN
#
#                                                  cast country  \
# 34  Dami Lee, Jason Lee, Bommie Catherine Han, Jen...     NaN
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
#
#             date_added  release_year rating   duration listed_in  \
# 34  September 17, 2021          2020  TV-Y7   1 Season  Kids' TV
# 39  September 16, 2021          2021  TV-Y7  3 Seasons  Kids' TV
#
#                                           description       date    year  \
# 34  Tayo speeds into an adventure when his friends... 2021-09-17  2021.0
# 39  A brave, energetic little boy with superhuman ... 2021-09-16  2021.0
#
#    Minutes     Unit
# 34       1   Season
# 39       3  Seasons

# %%
df[(df['type'] == 'Movie') & (df['listed_in'] == 'Dramas') | (df['type'] == 'TV Show') & (df['listed_in'] == "Kids' TV")]
# Out:
#      show_id     type                    title          director  \
# 34       s35  TV Show  Tayo and Little Wizards               NaN
# 39       s40  TV Show             Chhota Bheem               NaN
# 65       s66  TV Show             Numberblocks               NaN
# 89       s90  TV Show              Mighty Raju               NaN
# 100     s101  TV Show  Tobot Galaxy Detectives               NaN
# ...      ...      ...                      ...               ...
# 8691   s8692    Movie                Wakefield     Robin Swicord
# 8696   s8697    Movie                War Horse  Steven Spielberg
# 8783   s8784  TV Show                     Yoko               NaN
# 8785   s8786  TV Show                      YOM               NaN
# 8797   s8798  TV Show                Zak Storm               NaN
#
#                                                    cast  \
# 34    Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# ...

# %%
df['country'].value_counts().head(50)
# Out:
# United States                    2818
# India                             972
# United Kingdom                    419
# Japan                             245
# South Korea                       199
# Canada                            181
# Spain                             145
# France                            124
# Mexico                            110
# Egypt                             106
# Turkey                            105
# Nigeria                            95
# Australia                          87
# Taiwan                             81
# Indonesia                          79
# Brazil                             77
# Philippines                        75
# United Kingdom, United States      75
# United States, Canada              73
# Germany                            67
# China                              66
# Thailand                           61
# Argentina                          56
# Hong Kong                          53
# United States, United Kingdom      47
# ...

# %%
df[(df['country'] == 'Grenada')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, date, year, Minutes, Unit]
# Index: []

# %%
def segment_country (country):
    if country in ['United States', 'Canada', 'Mexico']
        return amerika;
    if country ['indonesia', 'banglades', 'india', 'japan']
        return asia;
# Out:
#   File "C:\Users\agian\AppData\Local\Temp/ipykernel_26192/548087008.py", line 2
#     if country in ['United States', 'Canada', 'Mexico']
#                                                        ^
# SyntaxError: invalid syntax
